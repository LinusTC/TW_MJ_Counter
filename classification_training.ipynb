# %%
# !pip install "numpy<2.0" "matplotlib<3.8" --force-reinstall
# !pip install ultralytics

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("/kaggle/input/mj-dataset/IR_model/yolo11m.pt")
model.train(data="/kaggle/input/mj-dataset/IR_model/Mahjong_dataset/data.yaml", imgsz=640, batch=8, epochs=30, workers=1, device=0)
# Out:
# Ultralytics 8.3.232 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r results.zip /kaggle/working
from IPython.display import FileLink
FileLink(r'results.zip')
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/runs/ (stored 0%)
#   adding: kaggle/working/runs/detect/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/BoxR_curve.png (deflated 13%)
#   adding: kaggle/working/runs/detect/train/val_batch1_labels.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/train/train_batch15462.jpg (deflated 6%)
#   adding: kaggle/working/runs/detect/train/weights/ (stored 0%)
#   adding: kaggle/working/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: kaggle/working/runs/detect/train/labels.jpg (deflated 42%)
#   adding: kaggle/working/runs/detect/train/train_batch15460.jpg (deflated 7%)
#   adding: kaggle/working/runs/detect/train/confusion_matrix_normalized.png (deflated 24%)
#   adding: kaggle/working/runs/detect/train/val_batch0_pred.jpg (deflated 5%)
# ...
